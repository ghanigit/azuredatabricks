# %% [markdown]
# # DBFS

# %% [markdown]
# ## DBUTILS

# %% [markdown]
# ### Service principle (Application Registration)
# ### Storage acccount
# ### azurekeyvault

# %% [markdown]
# ### App registration   - example -mydatabricksserviceprinciple
# app_id = "7deeee6e-564b-456f-9683-3c07339b88e6"
# directory_id = "37a8ed86-081b-4184-8874-1d13bd1d7d92"
# secrets = "J478Q~dykbz8miaz.IpVr9HMiaZnhDJ8Qhjpyddf"
#
# ### datalake storage - IAM - app (give access - storage blob data contributor(role) )
#
# ### - storage account name: mystrgacc988871
#
# service_credential = dbutils.secrets.get(scope="<secret-scope>",key="<service-credential-key>")
#
# spark.conf.set("fs.azure.account.auth.type.<storage-account>.dfs.core.windows.net", "OAuth")
# spark.conf.set("fs.azure.account.oauth.provider.type.<storage-account>.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
# spark.conf.set("fs.azure.account.oauth2.client.id.<storage-account>.dfs.core.windows.net", "<application-id>")
# spark.conf.set("fs.azure.account.oauth2.client.secret.<storage-account>.dfs.core.windows.net", service_credential)
# spark.conf.set("fs.azure.account.oauth2.client.endpoint.<storage-account>.dfs.core.windows.net", "https://login.microsoftonline.com/<directory-id>/oauth2/token")

# %%
spark.conf.set("fs.azure.account.auth.type.mystrgacc988871.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.mystrgacc988871.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.mystrgacc988871.dfs.core.windows.net", "7deeee6e-564b-456f-9683-3c07339b88e6")
spark.conf.set("fs.azure.account.oauth2.client.secret.mystrgacc988871.dfs.core.windows.net", "J478Q~dykbz8miaz.IpVr9HMiaZnhDJ8Qhjpyddf")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.mystrgacc988871.dfs.core.windows.net", "https://login.microsoftonline.com/37a8ed86-081b-4184-8874-1d13bd1d7d92/oauth2/token")

# %% [markdown]
# ###DBUTILS - Filesystem

# %%
dbutils.fs.ls("abfss://source@mystrgacc988871.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://source@mystrgacc988871.dfs.core.windows.net/sales.csv', name='sales.csv', size=3308303, modificationTime=1762134834000)]

# %% [markdown]
# ### DBUTILS - WIDGETS

# %%
dbutils.widgets.text("name","ghani")

# %%
dbutils.widgets.dropdown("country", "India", ["India","US","UK"], "Select Country")

# %%
var = dbutils.widgets.get("name")

# %%
var
# Out:
# 'ram'

# %% [markdown]
# ##secret scope

# %% [markdown]
# ###  create azure key vault - vault access policy (need to configure)
#
# ###  IAM - Add role assignment - key vault administrator - assign to user
#
# ###  create secret and name for the secret
#     Example: appsecret, J478Q~dykbz8miaz.IpVr9HMiaZnhDJ8Qhjpyddf
#
# ###  collect dns name and resources id of the keyvault
#       vault uri = https://mydemokeyvault34.vault.azure.net/
#       Resouce id = /subscriptions/ef2152a9-13b6-4efd-8bc5-72aab83890c8/resourceGroups/keyvaultrg/providers/Microsoft.KeyVault/vaults/mydemokeyvault34
#
# ### Create secret scope
#
#     databricks url = https://adb-2612869689978063.3.azuredatabricks.net
#     add #secrets/createScope
#          https://adb-2612869689978063.3.azuredatabricks.net#secrets/createScope

# %%
dbutils.secrets.listScopes()
# Out:
# [SecretScope(name='ghaniscope'), SecretScope(name='myscope')]

# %%
dbutils.secrets.list(scope='myscope')
# Out:
# [SecretMetadata(key='appsecret')]

# %%
dbutils.secrets.get(scope='myscope', key='appsecret')
# Out:
# '[REDACTED]'

# %%
service_credential = dbutils.secrets.get(scope='myscope',key='appsecret')
spark.conf.set("fs.azure.account.auth.type.mystrgacc988871.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.mystrgacc988871.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.mystrgacc988871.dfs.core.windows.net", "7deeee6e-564b-456f-9683-3c07339b88e6")
spark.conf.set("fs.azure.account.oauth2.client.secret.mystrgacc988871.dfs.core.windows.net", service_credential)
spark.conf.set("fs.azure.account.oauth2.client.endpoint.mystrgacc988871.dfs.core.windows.net", "https://login.microsoftonline.com/37a8ed86-081b-4184-8874-1d13bd1d7d92/oauth2/token")

# %%
dbutils.fs.ls("abfss://source@mystrgacc988871.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://source@mystrgacc988871.dfs.core.windows.net/sales.csv', name='sales.csv', size=3308303, modificationTime=1762134834000)]
